# %%
import pandas as pd

# %%
data = [['Akshit', 34] , ['Mohit', 25], ['Neha', 55], ['Manan', 23]]

# %%
data
# Out:
# [['Akshit', 34], ['Mohit', 25], ['Neha', 55], ['Manan', 23]]

# %%
pd.DataFrame(data, columns=["Name", "Marks"])
# Out:
#      Name  Marks
# 0  Akshit     34
# 1   Mohit     25
# 2    Neha     55
# 3   Manan     23
